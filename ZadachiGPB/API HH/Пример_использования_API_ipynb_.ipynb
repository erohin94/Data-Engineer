# %% [markdown]
# ## **Пример использования API:**

# %%
# Библиотека для работы с HTTP-запросами. Используем для обращения к API HH
import requests

# Пакет для удобной работы с данными в формате json
import json

# Модуль для работы со значением времени
import time


def get_page(page = 0):
    """
    Создаем метод для получения страницы со списком вакансий.
    Аргументы:
        page - Индекс страницы, начинается с 0. Значение по умолчанию 0, т.е. первая страница
    """

    # Справочник для параметров GET-запроса
    params = {
        'text': 'NAME:Аналитик', # Текст фильтра. В имени должно быть слово "Аналитик"
        'area': 1, # Поиск ощуществляется по вакансиям города Москва
        'page': page, # Индекс страницы поиска на HH
        'per_page': 100 # Кол-во вакансий на 1 странице
    }


    req = requests.get('https://api.hh.ru/vacancies', params) # Посылаем запрос к API
    data = req.content.decode() # Декодируем его ответ, чтобы Кириллица отображалась корректно
    req.close()
    return data

# Создаем список, в котором будут хранится ответы запроса к сервису API hh.ru
js_objs = []

# Считываем первые 2000 вакансий
for page in range(0, 20):

    # Преобразуем текст ответа запроса в словарь Python
    js_obj = json.loads(get_page(page))

    # Добавляем текущий ответ запроса в список
    js_objs.extend(js_obj["items"])

    # Проверка на последнюю страницу, если вакансий меньше 2000
    if (js_obj['pages'] - page) <= 1:
        break

    # Необязательная задержка, но чтобы не нагружать сервисы hh, оставим. 5 сек
    time.sleep(0.25)

print('Старницы поиска собраны')
# Out:
# Старницы поиска собраны

# %%
import pandas as pd

# Пример записи данных в DataFrame
df = pd.DataFrame(js_objs)
df.head()
# Out:
#           id  premium                                  name department  \
# 0  117722682    False  Политический аналитик / обозреватель       None
# 1  117148330    False                  Продуктовый аналитик       None
# 2  117489558    False                    Системный аналитик       None
# 3  117548289    False            Аналитик по товародвижению       None
# 4  116696632    False                   Финансовый аналитик       None
#
#    has_test  response_letter_required  \
# 0     False                     False
# 1     False                     False
# 2     False                     False
# 3     False                     False
# 4     False                     False
#
#                                                 area  \
# 0  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 1  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 2  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 3  {'id': '1', 'name': 'Москва', 'url': 'https://...
# ...
