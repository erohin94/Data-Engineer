# %% [markdown]
# # **JSON Общедоступные методы - Поиск вакансий - Поиск по вакансиям**

# %%
data = '''{
  "arguments": [
    {
      "argument": "area",
      "cluster_group": {
        "id": "area",
        "name": "Регион"
      },
      "disable_url": "https://...",
      "value": "1",
      "value_description": "Москва"
    },
    {
      "argument": "area",
      "cluster_group": {
        "id": "area",
        "name": "Регион"
      },
      "disable_url": "https://...",
      "value": "2",
      "value_description": "Санкт-Петербург"
    },
    {
      "argument": "text",
      "cluster_group": null,
      "disable_url": "https://...",
      "value": "менеджер по продажам",
      "value_description": null
    },
    {
      "argument": "search_field",
      "cluster_group": null,
      "disable_url": "https://...",
      "value": "name",
      "value_description": "в названии вакансии"
    },
    {
      "argument": "experience",
      "cluster_group": {
        "id": "experience",
        "name": "Опыт работы"
      },
      "disable_url": "https://...",
      "value": "between3And6",
      "value_description": "От 3 до 6 лет"
    },
    {
      "argument": "employment",
      "cluster_group": {
        "id": "employment",
        "name": "Тип занятости"
      },
      "disable_url": "https://...",
      "value": "full",
      "value_description": "Полная занятость"
    },
    {
      "argument": "schedule",
      "cluster_group": {
        "id": "schedule",
        "name": "График работы"
      },
      "disable_url": "https://...",
      "value": "fullDay",
      "value_description": "Полный день"
    },
    {
      "argument": "metro",
      "cluster_group": {
        "id": "metro",
        "name": "Метро"
      },
      "disable_url": "https://...",
      "hex_color": "13703a",
      "metro_type": "station",
      "value": "2.133",
      "value_description": "Сокол"
    },
    {
      "argument": "industry",
      "cluster_group": {
        "id": "industry",
        "name": "Отрасль компании"
      },
      "disable_url": "https://...",
      "value": "51",
      "value_description": "ЖКХ"
    },
    {
      "argument": "industry",
      "cluster_group": {
        "id": "sub_industry",
        "name": "Сфера компании"
      },
      "disable_url": "https://...",
      "value": "51.675",
      "value_description": "Энергосбережение"
    },
    {
      "argument": "label",
      "cluster_group": {
        "id": "label",
        "name": "Исключение"
      },
      "disable_url": "https://...",
      "value": "not_from_agency",
      "value_description": "Без вакансий агентств"
    },
    {
      "argument": "currency",
      "cluster_group": null,
      "disable_url": "https://...",
      "value": "USD",
      "value_description": null
    },
    {
      "argument": "only_with_salary",
      "cluster_group": {
        "id": "salary",
        "name": "Зарплата"
      },
      "disable_url": "https://...",
      "value": "true",
      "value_description": "Указана зарплата"
    },
    {
      "argument": "salary",
      "cluster_group": {
        "id": "salary",
        "name": "Зарплата"
      },
      "disable_url": "https://...",
      "value": "1500",
      "value_description": "от 1500 USD"
    },
    {
      "argument": "bottom_lat",
      "cluster_group": null,
      "disable_url": "https://...",
      "value": "55.58",
      "value_description": null
    },
    {
      "argument": "left_lng",
      "cluster_group": null,
      "disable_url": "https://...",
      "value": "37.52",
      "value_description": null
    },
    {
      "argument": "top_lat",
      "cluster_group": null,
      "disable_url": "https://...",
      "value": "55.74",
      "value_description": null
    },
    {
      "argument": "right_lng",
      "cluster_group": null,
      "disable_url": "https://...",
      "value": "37.86",
      "value_description": null
    },
    {
      "argument": "date_from",
      "cluster_group": null,
      "disable_url": "https://...",
      "value": "2017-02-01",
      "value_description": null
    },
    {
      "argument": "date_to",
      "cluster_group": null,
      "disable_url": "https://...",
      "value": "2017-02-10",
      "value_description": null
    },
    {
      "argument": "order_by",
      "cluster_group": null,
      "disable_url": "https://...",
      "value": "salary_desc",
      "value_description": "По убыванию зарплат"
    },
    {
      "argument": "sort_point_lat",
      "cluster_group": null,
      "disable_url": "https://...",
      "value": "55.74",
      "value_description": null
    },
    {
      "argument": "sort_point_lng",
      "cluster_group": null,
      "disable_url": "https://...",
      "value": "37.86",
      "value_description": null
    },
    {
      "argument": "period",
      "cluster_group": null,
      "disable_url": "https://...",
      "value": "7",
      "value_description": "За неделю"
    },
    {
      "argument": "employer_id",
      "cluster_group": null,
      "disable_url": "https://...",
      "value": "1455",
      "value_description": "HeadHunter"
    },
    {
      "argument": "search_period",
      "cluster_group": null,
      "disable_url": "https://...",
      "value": "7",
      "value_description": "За неделю"
    },
    {
      "argument": "no_magic",
      "cluster_group": null,
      "disable_url": "https://...",
      "value": "true",
      "value_description": null
    },
    {
      "argument": "host",
      "cluster_group": null,
      "disable_url": "https://...",
      "value": "hh.kz",
      "value_description": null
    },
    {
      "argument": "per_page",
      "cluster_group": null,
      "disable_url": "https://...",
      "value": "10",
      "value_description": null
    },
    {
      "argument": "page",
      "cluster_group": null,
      "disable_url": "https://...",
      "value": "0",
      "value_description": null
    },
    {
      "argument": "professional_role",
      "cluster_group": {
        "id": "professional_role",
        "name": "Профессиональная роль"
      },
      "disable_url": "https://...",
      "value": "90",
      "value_description": "Охранник"
    }
  ],
  "clusters": null,
  "fixes": null,
  "found": 13,
  "items": [
    {
      "accept_incomplete_resumes": false,
      "address": {
        "building": "9с10",
        "city": "Москва",
        "description": "На проходной потребуется паспорт",
        "lat": 55.807794,
        "lng": 37.638699,
        "metro_stations": [
          {
            "lat": 55.807794,
            "line_id": "6",
            "line_name": "Калужско-Рижская",
            "lng": 37.638699,
            "station_id": "6.8",
            "station_name": "Алексеевская"
          }
        ],
        "street": "улица Годовикова"
      },
      "alternate_url": "https://hh.ru/vacancy/8331228",
      "apply_alternate_url": "https://hh.ru/applicant/vacancy_response?vacancyId=8331228",
      "area": {
        "id": "1",
        "name": "Москва",
        "url": "https://api.hh.ru/areas/1"
      },
      "brand_snippet": {
        "background": {
          "color": null,
          "gradient": {
            "angle": 45,
            "color_list": [
              {
                "color": "#FF0000",
                "position": 10
              },
              {
                "color": "#FA0000",
                "position": 9
              }
            ]
          }
        },
        "logo": "https://hhcdn.ru/00001.png",
        "logo_scalable": {
          "default": {
            "height": 300,
            "url": "https://hhcdn.ru/00021.png",
            "width": 500
          },
          "xs": {
            "height": 100,
            "url": "https://hhcdn.ru/00022.png",
            "width": 200
          }
        },
        "logo_xs": "https://hhcdn.ru/00002.png",
        "picture": "https://hhcdn.ru/00003.png",
        "picture_scalable": {
          "default": {
            "height": 350,
            "url": "https://hhcdn.ru/00023.png",
            "width": 550
          },
          "xs": {
            "height": 150,
            "url": "https://hhcdn.ru/00024.png",
            "width": 250
          }
        },
        "picture_xs": "https://hhcdn.ru/00004.png"
      },
      "branding": {
        "tariff": "BASIC",
        "type": "CONSTRUCTOR"
      },
      "contacts": {
        "email": "user@example.com",
        "name": "Имя",
        "phones": [
          {
            "city": "985",
            "comment": null,
            "country": "7",
            "number": "000-00-00"
          }
        ]
      },
      "counters": {
        "responses": 0
      },
      "department": {
        "id": "HH-1455-TECH",
        "name": "HeadHunter::Технический департамент"
      },
      "employer": {
        "accredited_it_employer": false,
        "alternate_url": "https://hh.ru/employer/1455",
        "id": "1455",
        "logo_urls": {
          "90": "https://hh.ru/employer-logo/289027.png",
          "240": "https://hh.ru/employer-logo/289169.png",
          "original": "https://hh.ru/file/2352807.png"
        },
        "name": "HeadHunter",
        "trusted": true,
        "url": "https://api.hh.ru/employers/1455"
      },
      "has_test": true,
      "id": "8331228",
      "insider_interview": {
        "id": "12345",
        "url": "https://hh.ru/interview/12345?employerId=777"
      },
      "misleading_vacancy_alert": false,
      "name": "Секретарь",
      "professional_roles": [
        {
          "id": "90",
          "name": "Охранник"
        }
      ],
      "published_at": "2013-07-08T16:17:21+0400",
      "relations": [],
      "response_letter_required": true,
      "response_url": null,
      "salary": {
        "currency": "RUR",
        "from": 30000,
        "gross": true,
        "to": null
      },
      "schedule": {
        "id": "fullDay",
        "name": "Полный день"
      },
      "show_logo_in_search": true,
      "snippet": {
        "requirement": "Высшее образование. Опыт работы в качестве <highlighttext>секретаря</highlighttext>, офис-менеджера. Знание делопроизводства, документооборота. Коммуникативные навыки.",
        "responsibility": "Документооборот (регистрация, отправка, контроль исполнения писем, ведение протоколов, отчетность). Распределение корреспонденции. Прием и распределение телефонных звонков."
      },
      "sort_point_distance": 226.001293,
      "type": {
        "id": "open",
        "name": "Открытая"
      },
      "url": "https://api.hh.ru/vacancies/8331228"
    }
  ],
  "page": 0,
  "pages": 13,
  "per_page": 1,
  "suggests": null
}'''

# %% [markdown]
# # **Код Общедоступные методы - Поиск вакансий**

# %% [markdown]
# **Поиск по вакансиям**

# %%
import json
import pandas as pd

parsed_data = json.loads(data)
#Массив параметров поиска, переданных в запросе.
arguments = parsed_data["arguments"]
table_data = []

for item in arguments:
    argument_data = {
        'Argument': item['argument'],
        'Cluster Group': item['cluster_group']['name'] if item['cluster_group'] else None,
        'Cluster Group ID': item['cluster_group']['id'] if item['cluster_group'] else None,
        'Disable URL': item['disable_url'],
        'Value': item['value'],
        'Value Description': item['value_description']
    }
    table_data.append(argument_data)


df = pd.DataFrame(table_data)

df.to_excel('arguments_full_table.xlsx', index=False)

# %%
import json
import pandas as pd

parsed_data = json.loads(data)
#Список вакансий
items = parsed_data["items"]
items_data = []

items_data = []
for item in items:
    item_data = {
        'id': item['id'],
        'name': item['name'],
        'url': item['url'],
        'alternate_url': item['alternate_url'],
        'apply_alternate_url': item['apply_alternate_url'],
        'accept_incomplete_resumes': item.get('accept_incomplete_resumes'),
        'accept_temporary': item.get('accept_temporary'),
        'archived': item.get('archived'),
        'area_id': item['area']['id'] if item['area'] else None,
        'area_name': item['area']['name'] if item['area'] else None,
        'area_url': item['area']['url'] if item['area'] else None,
        'contacts_email': item['contacts']['email'] if item.get('contacts') else None,
        'contacts_name': item['contacts']['name'] if item.get('contacts') else None,
        'contacts_phones': item['contacts']['phones'] if item.get('contacts') else None,
        'created_at': item.get('created_at'),
        'department_id': item['department']['id'] if item['department'] else None,
        'department_name': item['department']['name'] if item['department'] else None,
        'employer_id': item['employer']['id'],
        'employer_name': item['employer']['name'],
        'employer_logo': item['employer']['logo_urls'].get('original') if item['employer'] else None,
        'has_test': item.get('has_test'),
        'insider_interview_id': item['insider_interview']['id'] if item.get('insider_interview') else None,
        'insider_interview_url': item['insider_interview']['url'] if item.get('insider_interview') else None,
        'internship': item.get('internship'),
        'night_shifts': item.get('night_shifts'),
        'premium': item.get('premium'),
        'professional_roles': [role['name'] for role in item['professional_roles']] if item.get('professional_roles') else None,
        'published_at': item.get('published_at'),
        'relations': item.get('relations'),
        'response_letter_required': item.get('response_letter_required'),
        'response_url': item.get('response_url'),
        'salary_currency': item['salary']['currency'] if item.get('salary') else None,
        'salary_from': item['salary']['from'] if item.get('salary') else None,
        'salary_to': item['salary']['to'] if item.get('salary') else None,
        'salary_gross': item['salary']['gross'] if item.get('salary') else None,
        'schedule_id': item['schedule']['id'] if item.get('schedule') else None,
        'schedule_name': item['schedule']['name'] if item.get('schedule') else None,
        'sort_point_distance': item.get('sort_point_distance'),
        'type_id': item['type']['id'] if item.get('type') else None,
        'type_name': item['type']['name'] if item.get('type') else None,
        'video_vacancy': item.get('video_vacancy')
    }


    items_data.append(item_data)

items_df = pd.DataFrame(items_data)
items_df.to_excel('items_full_table.xlsx', index=False)

# %% [markdown]
# # **JSON Общедоступные методы - Работодатель - Информация о работодателе**

# %%
data = '''{
  "accredited_it_employer": true,
  "alternate_url": "https://hh.ru/employer/1455",
  "applicant_services": {
    "target_employer": {
      "count": 2
    }
  },
  "area": {
    "id": "113",
    "name": "Россия",
    "url": "https://api.hh.ru/areas/113"
  },
  "branded_description": "<style>...</style><div>...</div><script></script>",
  "branding": {
    "makeup": {
      "url": "/employer/makeup/webview/12"
    },
    "template_code": "makeup:123",
    "template_version_id": "10",
    "type": "makeup"
  },
  "description": "Хороший работодатель",
  "id": "1455",
  "industries": [
    {
      "id": "7.540",
      "name": "Разработка программного обеспечения"
    },
    {
      "id": "9.399",
      "name": "Мобильная связь"
    }
  ],
  "insider_interviews": [
    {
      "id": "12345",
      "title": "Лучшие из лучших",
      "url": "https://hh.ru/interview/12345?employerId=1455"
    },
    {
      "id": "54321",
      "title": "История успеха",
      "url": "https://hh.ru/interview/54321?employerId=1455"
    }
  ],
  "logo_urls": {
    "90": "https://hh.ru/employer-logo/289027.png",
    "240": "https://hh.ru/employer-logo/289169.png",
    "original": "https://hh.ru/file/2352807.png"
  },
  "name": "HeadHunter",
  "open_vacancies": 19,
  "relations": [],
  "site_url": "https://hh.ru",
  "trusted": true,
  "type": "company",
  "vacancies_url": "https://api.hh.ru/vacancies?employer_id=1455"
}'''

# %% [markdown]
# # **Код Общедоступные методы - Работодатель**

# %% [markdown]
# **Информация о работодателе**

# %%
import json
import pandas as pd


parsed_data = json.loads(data)

table_data = [{
    'Employer ID': parsed_data.get("id"),
    'Employer Name': parsed_data.get("name"),
    'Employer Type': parsed_data.get("type"),
    'Description': parsed_data.get("description"),
    'Site URL': parsed_data.get("site_url"),
    'Vacancies URL': parsed_data.get("vacancies_url"),
    'Accredited': parsed_data.get("accredited_it_employer"),
    'Open Vacancies': parsed_data.get("open_vacancies"),
    'Trusted': parsed_data.get("trusted"),
    'Alternate URL': parsed_data.get("alternate_url"),
    'Branded Description': parsed_data.get("branded_description"),
    'Area ID': parsed_data.get("area", {}).get("id"),
    'Area Name': parsed_data.get("area", {}).get("name"),
    'Area URL': parsed_data.get("area", {}).get("url"),
    'Target Employer Count': parsed_data.get("applicant_services", {}).get("target_employer", {}).get("count"),
    'Makeup URL': parsed_data.get("branding", {}).get("makeup", {}).get("url"),
    'Template Code': parsed_data.get("branding", {}).get("template_code"),
    'Template Version ID': parsed_data.get("branding", {}).get("template_version_id"),
    'Branding Type': parsed_data.get("branding", {}).get("type"),
    'Industries': ', '.join([industry.get("name") for industry in parsed_data.get("industries", [])]),
    'Interviews': ', '.join([f'{interview.get("title")} ({interview.get("url")})' for interview in parsed_data.get("insider_interviews", [])]),
    'Logo 90px': parsed_data.get("logo_urls", {}).get("90"),
    'Logo 240px': parsed_data.get("logo_urls", {}).get("240"),
    'Logo Original': parsed_data.get("logo_urls", {}).get("original")
}]

df = pd.DataFrame(table_data)
df.to_excel('employer_data.xlsx', index=False)

# %% [markdown]
# # **JSON Общедоступные методы - Работодатель - Поиск работодателя**

# %%
data = '''{
  "found": 1,
  "items": [
    {
      "alternate_url": "https://hh.ru/employer/1455",
      "id": "1455",
      "logo_urls": {
        "90": "https://hh.ru/employer-logo/289027.png",
        "240": "https://hh.ru/employer-logo/289169.png",
        "original": "https://hh.ru/file/2352807.png"
      },
      "name": "HeadHunter",
      "open_vacancies": 19,
      "url": "https://api.hh.ru/employers/1455",
      "vacancies_url": "https://api.hh.ru/vacancies?employer_id=1455"
    }
  ],
  "page": 0,
  "pages": 1,
  "per_page": 20
}'''

# %% [markdown]
# # **Код Общедоступные методы - Работодатель**

# %% [markdown]
# **Поиск работодателя**

# %%
import json
import pandas as pd

parsed_data = json.loads(data)
items = parsed_data.get("items", [])
table_data = []

for item in items:
    item_data = {
        'Employer ID': item.get("id"),
        'Employer Name': item.get("name"),
        'Alternate URL': item.get("alternate_url"),
        'Vacancies URL': item.get("vacancies_url"),
        'Logo 90px': item.get("logo_urls", {}).get("90"),
        'Logo 240px': item.get("logo_urls", {}).get("240"),
        'Logo Original': item.get("logo_urls", {}).get("original"),
        'Open Vacancies': item.get("open_vacancies"),
        'URL': item.get("url")
    }
    table_data.append(item_data)


df = pd.DataFrame(table_data)
df.to_excel('employer_data.xlsx', index=False)
